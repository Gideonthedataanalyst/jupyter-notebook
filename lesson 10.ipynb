# %% [markdown]
# # PYTHON PANDAS

# %% [markdown]
# ## Slicing Python Pandas.

# %%
import pandas as pd

# %%
survey_df=pd.read_csv("Downloads/annual-enterprise-survey-2019-financial-year-provisional-csv (2) (1).csv")

# %%
survey_df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
survey_df.head(10)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
# 5  2019                     Level 1                99999       All industries
# 6  2019                     Level 1                99999       All industries
# 7  2019                     Level 1                99999       All industries
# 8  2019                     Level 1                99999       All industries
# 9  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
survey_df.tail(10)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32435  2013                     Level 3                 ZZ11
# 32436  2013                     Level 3                 ZZ11
# 32437  2013                     Level 3                 ZZ11
# 32438  2013                     Level 3                 ZZ11
# 32439  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 32435  Food product manufacturing  Dollars (millions)           H32
# 32436  Food product manufacturing  Dollars (millions)           H33
# 32437  Food product manufacturing             Dollars           H34
# ...

# %%
survey_df.sample(10)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 21139  2015                     Level 4                GH135
# 12633  2017                     Level 1                   LL
# 29577  2013                     Level 3                 DD12
# 20294  2015                     Level 3                 DD12
# 28471  2013                     Level 4                CC212
# 12467  2017                     Level 4                KK112
# 16955  2016                     Level 3                 JJ11
# 23110  2015                     Level 4                RS214
# 5742   2018                     Level 3                 CC53
# 22135  2015                     Level 1                   MN
#
#                                     Industry_name_NZSIOC               Units  \
# 21139           Non-Store and Commission Based Retailing  Dollars (millions)
# 12633            Rental, Hiring and Real Estate Services  Dollars (millions)
# ...

# %%
survey_df.describe()
# Out:
#                Year
# count  32445.000000
# mean    2016.000000
# std        2.000031
# min     2013.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2019.000000

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32445 entries, 0 to 32444
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         32445 non-null  int64
#  1   Industry_aggregation_NZSIOC  32445 non-null  object
#  2   Industry_code_NZSIOC         32445 non-null  object
#  3   Industry_name_NZSIOC         32445 non-null  object
#  4   Units                        32445 non-null  object
#  5   Variable_code                32445 non-null  object
#  6   Variable_name                32445 non-null  object
#  7   Variable_category            32445 non-null  object
#  8   Value                        32445 non-null  object
#  9   Industry_code_ANZSIC06       32445 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB

# %%
survey_df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
survey_df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
survey_df.isnull()
# Out:
#         Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      False                        False                 False
# 1      False                        False                 False
# 2      False                        False                 False
# 3      False                        False                 False
# 4      False                        False                 False
# ...      ...                          ...                   ...
# 32440  False                        False                 False
# 32441  False                        False                 False
# 32442  False                        False                 False
# 32443  False                        False                 False
# 32444  False                        False                 False
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                     False  False          False          False
# ...

# %%
survey_df.isnull().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
survey_df["Value"].sample(12)
# Out:
# 31934      184
# 4278        43
# 15425    3,437
# 21044       18
# 23936      422
# 899        263
# 17722    9,679
# 851         52
# 26430       13
# 25890    79600
# 15276    2,154
# 18234    1,112
# Name: Value, dtype: object

# %%
survey_df["Value"].sample(12).describe()
# Out:
# count     12
# unique    11
# top        7
# freq       2
# Name: Value, dtype: object

# %%
survey_df["Value"].sample(12).info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 12 entries, 20389 to 4528
# Series name: Value
# Non-Null Count  Dtype
# --------------  -----
# 12 non-null     object
# dtypes: object(1)
# memory usage: 192.0+ bytes

# %%
survey_df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
survey_df[["Units","Value"]]
# Out:
#                     Units    Value
# 0      Dollars (millions)  728,239
# 1      Dollars (millions)  643,809
# 2      Dollars (millions)   62,924
# 3      Dollars (millions)   21,505
# 4      Dollars (millions)  634,710
# ...                   ...      ...
# 32440          Percentage       52
# 32441          Percentage       40
# 32442          Percentage       12
# 32443          Percentage        5
# 32444          Percentage       46
#
# [32445 rows x 2 columns]

# %%
survey_df[["Units","Value"]].head(12)
# Out:
#                  Units    Value
# 0   Dollars (millions)  728,239
# 1   Dollars (millions)  643,809
# 2   Dollars (millions)   62,924
# 3   Dollars (millions)   21,505
# 4   Dollars (millions)  634,710
# 5   Dollars (millions)   35,250
# 6   Dollars (millions)    7,458
# 7   Dollars (millions)   20,977
# 8   Dollars (millions)  112,960
# 9   Dollars (millions)      206
# 10  Dollars (millions)    1,767
# 11  Dollars (millions)  445,481

# %%
survey_df[["Units","Value"]].tail(12)
# Out:
#                     Units   Value
# 32433  Dollars (millions)   23102
# 32434  Dollars (millions)   10670
# 32435  Dollars (millions)   10212
# 32436  Dollars (millions)    2220
# 32437             Dollars  523700
# 32438             Dollars   17700
# 32439          Percentage      91
# 32440          Percentage      52
# 32441          Percentage      40
# 32442          Percentage      12
# 32443          Percentage       5
# 32444          Percentage      46

# %%
survey_df[["Units","Value"]].sample(12)
# Out:
#                     Units   Value
# 28838          Percentage      11
# 20457  Dollars (millions)       4
# 22541  Dollars (millions)   1,081
# 11657  Dollars (millions)   6,760
# 15728  Dollars (millions)   1,410
# 12069  Dollars (millions)       1
# 3934   Dollars (millions)     349
# 23896  Dollars (millions)       1
# 32012  Dollars (millions)     177
# 17474  Dollars (millions)   1,310
# 13047             Dollars  22,600
# 25426          Percentage      31

# %%
survey_df[["Units","Value"]].sample(12).describe()
# Out:
#                      Units    Value
# count                   12       12
# unique                   3       12
# top     Dollars (millions)  205,600
# freq                     8        1

# %%
survey_df[["Units","Value"]].sample(12).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2479 to 8652
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Units   12 non-null     object
#  1   Value   12 non-null     object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
survey_df[["Units","Value"]].sample(12).isnull()
# Out:
#        Units  Value
# 5245   False  False
# 7593   False  False
# 26772  False  False
# 20001  False  False
# 28383  False  False
# 32011  False  False
# 25928  False  False
# 30767  False  False
# 8442   False  False
# 18605  False  False
# 10252  False  False
# 20805  False  False

# %%
survey_df[["Units","Value"]].sample(12).isnull().sum()
# Out:
# Units    0
# Value    0
# dtype: int64

# %%
new_df1=survey_df[["Variable_category","Value"]].sample(8)

# %%
new_df1
# Out:
#            Variable_category   Value
# 21178     Financial position   2,370
# 13775  Financial performance      10
# 10458  Financial performance     285
# 15389     Financial position   6,219
# 13878  Financial performance     909
# 1874   Financial performance   9,544
# 31951  Financial performance     330
# 6580   Financial performance  12,016

# %%
new_df1.describe()
# Out:
#             Variable_category  Value
# count                       8      8
# unique                      2      8
# top     Financial performance  2,370
# freq                        6      1

# %%
new_df1.Value.describe()
# Out:
# count         8
# unique        8
# top       2,370
# freq          1
# Name: Value, dtype: object

# %%
new_df1
# Out:
#            Variable_category   Value
# 21178     Financial position   2,370
# 13775  Financial performance      10
# 10458  Financial performance     285
# 15389     Financial position   6,219
# 13878  Financial performance     909
# 1874   Financial performance   9,544
# 31951  Financial performance     330
# 6580   Financial performance  12,016

# %%
# Saving newdf1 dataframe to csv
new_df1.to_csv("Python Sonek new_df1.csv")

# %%
survey_df[0:20]
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2019                     Level 1                99999
# 1   2019                     Level 1                99999
# 2   2019                     Level 1                99999
# 3   2019                     Level 1                99999
# 4   2019                     Level 1                99999
# 5   2019                     Level 1                99999
# 6   2019                     Level 1                99999
# 7   2019                     Level 1                99999
# 8   2019                     Level 1                99999
# 9   2019                     Level 1                99999
# 10  2019                     Level 1                99999
# 11  2019                     Level 1                99999
# 12  2019                     Level 1                99999
# 13  2019                     Level 1                99999
# 14  2019                     Level 1                99999
# ...

# %%
survey_df[32440:32445]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
# 32444  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 32440                          Quick ratio  Financial ratios    52
# 32441  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
survey_df[32440:32446]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
# 32444  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 32440                          Quick ratio  Financial ratios    52
# 32441  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
survey_df[32440:32444]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
#
#                              Variable_name Variable_category Value  \
# 32440                          Quick ratio  Financial ratios    52
# 32441  Margin on sales of goods for resale  Financial ratios    40
# 32442                     Return on equity  Financial ratios    12
# 32443               Return on total assets  Financial ratios     5
#
# ...

# %%
#survey_df[start:stop:stepby]
survey_df[32400:32444:5]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32400  2013                     Level 4                RS214
# 32405  2013                     Level 4                RS214
# 32410  2013                     Level 3                 ZZ11
# 32415  2013                     Level 3                 ZZ11
# 32420  2013                     Level 3                 ZZ11
# 32425  2013                     Level 3                 ZZ11
# 32430  2013                     Level 3                 ZZ11
# 32435  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
#
#                                 Industry_name_NZSIOC               Units  \
# 32400  Civil, Professional and Other Interest Groups  Dollars (millions)
# 32405  Civil, Professional and Other Interest Groups          Percentage
# 32410                     Food product manufacturing  Dollars (millions)
# ...

# %%
survey_df[-6:-1]
#reverse indexing
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32439  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32439  Food product manufacturing  Percentage           H36
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
#
#                              Variable_name Variable_category Value  \
# 32439                        Current ratio  Financial ratios    91
# 32440                          Quick ratio  Financial ratios    52
# ...

# %%
survey_df[-5::]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
# 32444  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 32440                          Quick ratio  Financial ratios    52
# 32441  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
survey_df[-6:32445]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32439  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32439  Food product manufacturing  Percentage           H36
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
# 32444  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# ...

# %% [markdown]
# # LOC AND ILOC FUNCTIONS.

# %%
#Loc and Iloc allows us to work with the slicing of rows and columns together.

# %% [markdown]
# ## ILOC

# %%
# iloc==>columns can only be considered as indices
# for iloc we cannot refer to columns by their string names
# (start:stop:stepby, start:stop:stepby)
# (Row,Column)

# %%
#survey_df.iloc[row,column]
survey_df.iloc[32400:32445:5,4:10:1]
# Out:
#                     Units Variable_code                         Variable_name  \
# 32400  Dollars (millions)           H32                   Current liabilities
# 32405          Percentage           H37                           Quick ratio
# 32410  Dollars (millions)           H02  Sales of goods not further processed
# 32415  Dollars (millions)           H08                     Total expenditure
# 32420  Dollars (millions)           H13              Redundancy and severance
# 32425  Dollars (millions)           H22                        Closing stocks
# 32430  Dollars (millions)           H27             Additions to fixed assets
# 32435  Dollars (millions)           H32                   Current liabilities
# 32440          Percentage           H37                           Quick ratio
#
#            Variable_category  Value  \
# 32400     Financial position    797
# 32405       Financial ratios    314
# 32410  Financial performance   2808
# 32415  Financial performance  35502
# ...

# %%
survey_df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
survey_df.iloc[32400:32445:5,4::]
# Out:
#                     Units Variable_code                         Variable_name  \
# 32400  Dollars (millions)           H32                   Current liabilities
# 32405          Percentage           H37                           Quick ratio
# 32410  Dollars (millions)           H02  Sales of goods not further processed
# 32415  Dollars (millions)           H08                     Total expenditure
# 32420  Dollars (millions)           H13              Redundancy and severance
# 32425  Dollars (millions)           H22                        Closing stocks
# 32430  Dollars (millions)           H27             Additions to fixed assets
# 32435  Dollars (millions)           H32                   Current liabilities
# 32440          Percentage           H37                           Quick ratio
#
#            Variable_category  Value  \
# 32400     Financial position    797
# 32405       Financial ratios    314
# 32410  Financial performance   2808
# 32415  Financial performance  35502
# ...

# %%
survey_df.iloc[32400:32445:5,:]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32400  2013                     Level 4                RS214
# 32405  2013                     Level 4                RS214
# 32410  2013                     Level 3                 ZZ11
# 32415  2013                     Level 3                 ZZ11
# 32420  2013                     Level 3                 ZZ11
# 32425  2013                     Level 3                 ZZ11
# 32430  2013                     Level 3                 ZZ11
# 32435  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
#
#                                 Industry_name_NZSIOC               Units  \
# 32400  Civil, Professional and Other Interest Groups  Dollars (millions)
# 32405  Civil, Professional and Other Interest Groups          Percentage
# 32410                     Food product manufacturing  Dollars (millions)
# ...

# %% [markdown]
# ## LOC function.

# %%
#survey_df.loc[row,column]
survey_df.loc[32400:32445:5, "Year"::]
# loc works with string column names
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32400  2013                     Level 4                RS214
# 32405  2013                     Level 4                RS214
# 32410  2013                     Level 3                 ZZ11
# 32415  2013                     Level 3                 ZZ11
# 32420  2013                     Level 3                 ZZ11
# 32425  2013                     Level 3                 ZZ11
# 32430  2013                     Level 3                 ZZ11
# 32435  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
#
#                                 Industry_name_NZSIOC               Units  \
# 32400  Civil, Professional and Other Interest Groups  Dollars (millions)
# 32405  Civil, Professional and Other Interest Groups          Percentage
# 32410                     Food product manufacturing  Dollars (millions)
# ...

# %%
survey_df.loc[32400:32445:5,["Year","Value"]]
# Out:
#        Year  Value
# 32400  2013    797
# 32405  2013    314
# 32410  2013   2808
# 32415  2013  35502
# 32420  2013      8
# 32425  2013   4041
# 32430  2013   1339
# 32435  2013  10212
# 32440  2013     52

# %%
survey_df.loc[::,"Year":"Variable_name":2]
# Out:
#        Year Industry_code_NZSIOC               Units  \
# 0      2019                99999  Dollars (millions)
# 1      2019                99999  Dollars (millions)
# 2      2019                99999  Dollars (millions)
# 3      2019                99999  Dollars (millions)
# 4      2019                99999  Dollars (millions)
# ...     ...                  ...                 ...
# 32440  2013                 ZZ11          Percentage
# 32441  2013                 ZZ11          Percentage
# 32442  2013                 ZZ11          Percentage
# 32443  2013                 ZZ11          Percentage
# 32444  2013                 ZZ11          Percentage
#
#                                          Variable_name
# 0                                         Total income
# 1      Sales, government funding, grants and subsidies
# 2                    Interest, dividends and donations
# 3                                 Non-operating income
# ...

# %%
survey_df.loc[::,"Year":"Variable_name":2].sample(12)
# Out:
#        Year Industry_code_NZSIOC               Units  \
# 8956   2018                   RS  Dollars (millions)
# 1716   2019                 DD11  Dollars (millions)
# 27739  2014                RS212          Percentage
# 30629  2013                II111          Percentage
# 4264   2019                QQ112  Dollars (millions)
# 7396   2018                 II11  Dollars (millions)
# 11706  2017                GH131  Dollars (millions)
# 23085  2015                RS212  Dollars (millions)
# 8511   2018                MN211             Dollars
# 9900   2017                CC211             Dollars
# 4238   2019                QQ111  Dollars (millions)
# 14036  2016                 AA12  Dollars (millions)
#
#                                 Variable_name
# 8956   Purchases and other operating expenses
# 1716                           Indirect taxes
# 27739                        Return on equity
# 30629                        Return on equity
# ...

# %% [markdown]
# # Subsetting Data Using some Criteria.

# %%
#showing our table only where the year is 2018
survey_df[survey_df.Year==2018]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 4635  2018                     Level 1                99999
# 4636  2018                     Level 1                99999
# 4637  2018                     Level 1                99999
# 4638  2018                     Level 1                99999
# 4639  2018                     Level 1                99999
# ...    ...                         ...                  ...
# 9265  2018                     Level 3                 ZZ11
# 9266  2018                     Level 3                 ZZ11
# 9267  2018                     Level 3                 ZZ11
# 9268  2018                     Level 3                 ZZ11
# 9269  2018                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 4635              All industries  Dollars (millions)           H01
# 4636              All industries  Dollars (millions)           H04
# ...

# %%
survey_df[survey_df.Year==2018].sample(12)
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 5257  2018                     Level 4                CC211
# 4645  2018                     Level 1                99999
# 8516  2018                     Level 4                MN211
# 7700  2018                     Level 3                 JJ12
# 5816  2018                     Level 3                 CC61
# 7660  2018                     Level 3                 JJ11
# 8577  2018                     Level 4                MN213
# 5726  2018                     Level 4                CC523
# 9148  2018                     Level 4                RS211
# 6526  2018                     Level 4                EE113
# 8218  2018                     Level 4                LL123
# 5862  2018                     Level 4                CC611
#
#                                    Industry_name_NZSIOC               Units  \
# 5257                  Textile and Leather Manufacturing  Dollars (millions)
# ...

# %%
#showing our table only where the value column is C
survey_df[survey_df.Value=='C']
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 427    2019                     Level 1                   BB
# 429    2019                     Level 1                   BB
# 685    2019                     Level 3                 CC31
# 721    2019                     Level 4                CC311
# 747    2019                     Level 3                 CC32
# ...     ...                         ...                  ...
# 32260  2013                     Level 4                RS113
# 32290  2013                     Level 3                 RS21
# 32386  2013                     Level 4                RS214
# 32412  2013                     Level 3                 ZZ11
# 32413  2013                     Level 3                 ZZ11
#
#                                     Industry_name_NZSIOC               Units  \
# 427                                               Mining  Dollars (millions)
# ...

# %%
#showing our table only where the value column is C
survey_df[survey_df.Value=='C'].describe()
# Out:
#               Year
# count  1593.000000
# mean   2015.877589
# std       1.966288
# min    2013.000000
# 25%    2014.000000
# 50%    2016.000000
# 75%    2018.000000
# max    2019.000000

# %%
#showing our table only where the years fall between 2015 and 2020
survey_df[(survey_df.Year>2015)&(survey_df.Year<2020)]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 18535  2016                     Level 3                 ZZ11
# 18536  2016                     Level 3                 ZZ11
# 18537  2016                     Level 3                 ZZ11
# 18538  2016                     Level 3                 ZZ11
# 18539  2016                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
#showing our table only where the years fall between 2015 and 2020
survey_df[(survey_df.Year>2015)&(survey_df.Year<2020)].sample(7)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 12228  2017                     Level 4                II133
# 5862   2018                     Level 4                CC611
# 16748  2016                     Level 3                 II12
# 16911  2016                     Level 1                   JJ
# 15025  2016                     Level 3                 CC53
# 11636  2017                     Level 3                 GH12
# 17437  2016                     Level 4                LL122
#
#                                     Industry_name_NZSIOC               Units  \
# 12228                   Warehousing and Storage Services  Dollars (millions)
# 5862          Non-Metallic Mineral Product Manufacturing  Dollars (millions)
# 16748               Rail, Water, Air and Other Transport  Dollars (millions)
# 16911           Information Media and Telecommunications  Dollars (millions)
# 15025   Polymer Product and Rubber Product Manufacturing  Dollars (millions)
# ...
