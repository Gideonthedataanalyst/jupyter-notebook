# %% [markdown]
# # PYTHON PANDAS

# %% [markdown]
# ## Reading from an external file.

# %%
import pandas as pd

# %%
product_df=pd.read_csv("Product (2).csv")

# %%
product_df
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore

# %%
product_df.head()
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi

# %%
product_df.tail()
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore

# %%
product_df.sample()
# Out:
#    Product_ID Product_Name Category  Price Seller_City
# 2         103        Shoes  Fashion   2999     Chennai

# %%
product_df.sample()
# Out:
#    Product_ID Product_Name Category  Price Seller_City
# 0         101        Watch  Fashion    299       Delhi

# %%
product_df.sample(3)
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 4         105        Books        Study    145       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 6         107       Laptop  Electronics  79999   Bengalore

# %% [markdown]
# ## Descriptive statistics

# %%
product_df.describe()
# Out:
#        Product_ID         Price
# count    7.000000      7.000000
# mean   104.000000  14271.571429
# std      2.160247  29467.509712
# min    101.000000    110.000000
# 25%    102.500000    222.000000
# 50%    104.000000   1350.000000
# 75%    105.500000   8999.000000
# max    107.000000  79999.000000

# %%
#mean is not so desirable here because it is affected by extreme values i.e. outliers

# %%
product_df
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore

# %%
# to see our columns 
product_df.columns
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Price', 'Seller_City'], dtype='object')

# %%
# to check the data types of your dataframe 
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    7 non-null      int64
#  1   Product_Name  7 non-null      object
#  2   Category      7 non-null      object
#  3   Price         7 non-null      int64
#  4   Seller_City   7 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 412.0+ bytes

# %%
survey_df=pd.read_csv("annual-enterprise-survey-2019-financial-year-provisional.csv")

# %%
survey_df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
survey_df.head(8)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
# 5  2019                     Level 1                99999       All industries
# 6  2019                     Level 1                99999       All industries
# 7  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
# 5  Dollars (millions)           H09
# ...

# %%
survey_df.tail(7)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32438  2013                     Level 3                 ZZ11
# 32439  2013                     Level 3                 ZZ11
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32438  Food product manufacturing     Dollars           H35
# 32439  Food product manufacturing  Percentage           H36
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
# ...

# %%
survey_df.sample(6)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 30184  2013                     Level 3                 GH12
# 766    2019                     Level 3                 CC32
# 27739  2014                     Level 4                RS212
# 14653  2016                     Level 3                 CC32
# 12621  2017                     Level 1                   LL
# 5585   2018                     Level 4                CC511
#
#                                     Industry_name_NZSIOC               Units  \
# 30184  Supermarket, Grocery Stores and Specialised Fo...  Dollars (millions)
# 766    Pulp, Paper and Converted Paper Product Manufa...  Dollars (millions)
# 27739  Personal Care, Funeral and Other Personal Serv...          Percentage
# 14653  Pulp, Paper and Converted Paper Product Manufa...  Dollars (millions)
# 12621            Rental, Hiring and Real Estate Services  Dollars (millions)
# ...

# %%
survey_df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
survey_df.describe()
# Out:
#                Year
# count  32445.000000
# mean    2016.000000
# std        2.000031
# min     2013.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2019.000000

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32445 entries, 0 to 32444
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         32445 non-null  int64
#  1   Industry_aggregation_NZSIOC  32445 non-null  object
#  2   Industry_code_NZSIOC         32445 non-null  object
#  3   Industry_name_NZSIOC         32445 non-null  object
#  4   Units                        32445 non-null  object
#  5   Variable_code                32445 non-null  object
#  6   Variable_name                32445 non-null  object
#  7   Variable_category            32445 non-null  object
#  8   Value                        32445 non-null  object
#  9   Industry_code_ANZSIC06       32445 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB

# %%
survey_df.index
# Out:
# RangeIndex(start=0, stop=32445, step=1)

# %% [markdown]
# ## slicing columns

# %%
survey_df["Year"]
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32440    2013
# 32441    2013
# 32442    2013
# 32443    2013
# 32444    2013
# Name: Year, Length: 32445, dtype: int64

# %%
survey_df["Year"].head(5)
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# Name: Year, dtype: int64

# %%
survey_df["Year"].sample(5)
# Out:
# 15887    2016
# 30950    2013
# 19678    2015
# 17116    2016
# 20506    2015
# Name: Year, dtype: int64

# %%
survey_df["Year"].tail(5)
# Out:
# 32440    2013
# 32441    2013
# 32442    2013
# 32443    2013
# 32444    2013
# Name: Year, dtype: int64
